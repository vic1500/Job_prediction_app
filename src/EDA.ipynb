# %%
import pandas as pd

# %%
df = pd.read_csv('data/ai_job_dataset.csv')
df.head()
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             EUR
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# 3              India            50
# ...

# %%
from utils.plot_utils import top_ten_skills, salary_by_industry

salary_by_industry(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 3
#       1 from utils.plot_utils import top_ten_skills, salary_by_industry
# ----> 3 salary_by_industry(df)
#
# File c:\Users\Dman\Documents\Programming\Machine_learning\ML_bootcamp_2425\AI_job_prediction_app\src\utils\plot_utils.py:32, in salary_by_industry(df)
#      31 def salary_by_industry(df):
# ---> 32     industry_salary = df.groupby('industry')['salary_usd'].mean().sort_values(ascending=False)
#      33     fig = px.bar(
#      34         industry_salary,
#      35         x=industry_salary.index,
#    (...)
#      38         title="Average Salary by Industry"
#      39     )
#      40     st.plotly_chart(fig)
#
# File c:\Users\Dman\.conda\envs\sklearn_env_3.12\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
# ...

# %%
import plotly.express as px
import streamlit as st
import matplotlib.pyplot as plt 

industry_salary = df.groupby('industry')['salary_usd'].mean().sort_values(ascending=False)

industry_salary = industry_salary.reset_index()
industry_salary.columns = ['Industry', 'Average Salary']

industry_salary
# Out:
#               Industry  Average Salary
# 0           Consulting   117602.142157
# 1        Manufacturing   116162.888773
# 2                Media   116127.730144
# 3            Education   116026.803347
# 4          Real Estate   115919.095333
# 5           Technology   115831.823937
# 6           Government   115694.321643
# 7              Finance   115323.398374
# 8   Telecommunications   115291.411234
# 9               Energy   115188.436475
# 10      Transportation   114837.802407
# 11              Retail   114776.363123
# 12          Healthcare   114433.883651
# 13          Automotive   113987.241176
# 14              Gaming   112979.574974
